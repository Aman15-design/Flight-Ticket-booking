# %% [markdown]
# # FLY WITH US

# %% [markdown]
# Book flights to internation destinationS with us.

# %%
import pandas as pd
print("Enter name of the city:")
print("Available Sources: Delhi and Mumbai")
print("Available destinations: New York,London,Seoul,Sydney and Zurich")
from_city=str(input("From "))
destination_city=str(input("To "))
f=str(from_city.upper())
d=str(destination_city.upper())
print()
print()
if(f=="DELHI" and d=="NEW YORK"):
    print("----------------------------------------DELHI TO NEW YORK----------------------------------------")
    print()
    df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_D_NY.xlsx')
    df_air
    m=1
elif(f=="DELHI" and d=="LONDON"):
    print("----------------------------------------DELHI TO LONDON----------------------------------------")
    print()
    df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_D_L.xlsx')
    df_air
    m=2
elif(f=="DELHI" and d=="SEOUL"):
    print("----------------------------------------DELHI TO SEOUL----------------------------------------")
    print()
    df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_D_SO.xlsx')
    df_air
    m=3
elif(f=="DELHI" and d=="ZURICH"):
    print("----------------------------------------DELHI TO ZURICH----------------------------------------")
    print()
    df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_D_Z.xlsx')
    df_air
    m=4
elif(f=="DELHI" and d=="SYDNEY"):
    print("----------------------------------------DELHI TO SYDNEY----------------------------------------")
    print()
    df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_D_SY.xlsx')
    df_air
    m=5
elif(f=="MUMBAI" and d=="LONDON"):
    print("----------------------------------------MUMBAI TO LONDON----------------------------------------")
    print()
    df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_M_L.xlsx')
    df_air
    m=6
elif(f=="MUMBAI" and d=="SEOUL"):
    print("----------------------------------------MUMBAI TO SEOUL----------------------------------------")
    print()
    df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_M_SO.xlsx')
    df_air
    m=7
elif(f=="MUMBAI" and d=="ZURICH"):
    print("----------------------------------------MUMBAI TO ZURICH----------------------------------------")
    print()
    df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_M_Z.xlsx')
    df_air
    m=8
elif(f=="MUMBAI" and d=="SYDNEY"):
    print("----------------------------------------MUMBAI TO SYDNEY----------------------------------------")
    print()
    df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_M_SY.xlsx')
    df_air
    m=9
elif(f=="MUMBAI" and d=="NEW YORK"):
    print("----------------------------------------MUMBAI TO NEW YORK----------------------------------------")
    print()
    df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_M_NY.xlsx')
    df_air
    m=10
else:
    print("Sorry!!!!.......No flights available from ",f," to ",d)
    m=0
# Out:
# Enter name of the city:
# Available Sources: Delhi and Mumbai
# Available destinations: New York,London,Seoul,Sydney and Zurich
# From DELHI
# To LONDON
#
#
# ----------------------------------------DELHI TO LONDON----------------------------------------

# %%
df_air
# Out:
#                       AIRLINES DEPARTURE DURATION   ARRIVAL  PRICE  SEATS  \
# 0              BRITISH AIRWAYS  00:30:00  09H 25M  10:55:00  33564     98
# 1              BRITISH AIRWAYS  03:45:00  09H 30M  13:15:00  32342     52
# 2                    AIR INDIA  08:00:00  10H 05M  18:00:00  27346     76
# 3      VIRGIN ATLANTIC AIRWAYS  11:15:00  09H 20M  20:35:00  38576     98
# 4      VIRGIN ATLANTIC AIRWAYS  14:50:00  09H 20M  00:10:00  38525     72
# 5  SWISS INTERNATIONAL AIRWAYS  16:20:00  19H 40M  11:20:00  41029     64
# 6                     EMIRATES  18:15:00  15H 15M  09:00:00  38354     69
# 7                    LUFTHANSA  23:30:00  16H 30M  15:30:00  41781     87
# 8                     EMIRATES  17:10:00  12H 53M  13:20:00  42982     88
# 9                    AIR INDIA  18:04:00  14H 06M  06:30:00  39277     67
#
#     CODE
# 0  OF94C
# 1  PC7OC
# 2  SK93V
# 3  NV03N
# 4  PG24X
# 5  QR15N
# 6  4E23N
# 7  XM93F
# 8  MZ24G
# 9  TB92G

# %%
import matplotlib.pyplot as plt

# %%
y = df_air.PRICE
x = df_air.AIRLINES
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,2.0,2.0])
axes.plot(x,y,'b',linewidth = 5,alpha = 1 , linestyle = 'solid',marker='o',markersize=20,markeredgecolor='black')
axes.set_xlabel('AIRLINES')
axes.set_ylabel('PRCE')
axes.set_title("")
# Out:
# Text(0.5, 1.0, '')

# %%
y = df_air.DURATION
x = df_air.AIRLINES
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,2.0,2.0])
axes.plot(x,y,color = 'blue',linewidth = 5,alpha = 1 , linestyle = 'solid',marker='o',markersize=20,markeredgecolor='black')
axes.set_xlabel('AIRLINES')
axes.set_ylabel('DURATION')
axes.set_title("")
# Out:
# Text(0.5, 1.0, '')

# %%
df_air['SEATS'].value_counts().plot(kind='pie',figsize=(5,5))
plt.show()

# %%
def book():
    j=str(input("Please choose the serial number of airline you want:"))
    return j

# %%
print("Sort the above dataset:")
print("1.Sort by duration")
print("2.Sort by price")
choice=int(input("Enter your choice:"))
if (choice==int(1)):
    if(m==1):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_D_NY - ST.xlsx')
    elif(m==2):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_D_L - ST.xlsx')
    elif(m==3):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_D_SO - ST.xlsx')
    elif(m==4):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_D_Z - ST.xlsx')
    elif(m==5):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_D_SY - ST.xlsx')
    elif(m==6):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_M_L - ST.xlsx')
    elif(m==7):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_M_SO - ST.xlsx')
    elif(m==8):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_M_Z - ST.xlsx')
    elif(m==9):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_M_SY - SP.xlsx')
    elif(m==10):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_M_NY - ST.xlsx')
elif(choice==2):
    if(m==1):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_D_NY - SP.xlsx')
    elif(m==2):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_D_L - SP.xlsx')
    elif(m==3):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_D_SO - SP.xlsx')
    elif(m==4):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_D_Z - SP.xlsx')
    elif(m==5):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_D_SY - SP.xlsx')
    elif(m==6):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_M_L - SP.xlsx')
    elif(m==7):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_M_SO - SP.xlsx')
    elif(m==8):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_M_Z - SP.xlsx')
    elif(m==9):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_M_SY - ST.xlsx')
    elif(m==10):
        df_air=pd.read_excel(r'E:\AIR_PYTHON\AIR_M_NY - SP.xlsx')
df_air
# Out:
# Sort the above dataset:
# 1.Sort by duration
# 2.Sort by price
# Enter your choice:2
#                       AIRLINES DEPARTURE DURATION   ARRIVAL  PRICE  SEATS  \
# 0                    AIR INDIA  08:00:00  10H 05M  18:00:00  27346     76
# 1              BRITISH AIRWAYS  03:45:00  09H 30M  13:15:00  32342     52
# 2              BRITISH AIRWAYS  00:30:00  09H 25M  10:55:00  33564     98
# 3                     EMIRATES  18:15:00  15H 15M  09:00:00  38354     69
# 4      VIRGIN ATLANTIC AIRWAYS  14:50:00  09H 20M  00:10:00  38525     72
# 5      VIRGIN ATLANTIC AIRWAYS  11:15:00  09H 20M  20:35:00  38576     98
# 6                    AIR INDIA  18:04:00  14H 06M  06:30:00  39277     67
# 7  SWISS INTERNATIONAL AIRWAYS  16:20:00  19H 40M  11:20:00  41029     64
# 8                    LUFTHANSA  23:30:00  16H 30M  15:30:00  41781     87
# 9                     EMIRATES  17:10:00  12H 53M  13:20:00  42982     88
#
#     CODE
# 0  SK93V
# 1  PC7OC
# 2  OF94C
# 3  4E23N
# 4  PG24X
# ...

# %%
p=int(input("Enter the maximum price limit: "))
df_air[df_air['PRICE']<p]
# Out:
# Enter the maximum price limit: 40000
#                   AIRLINES DEPARTURE DURATION   ARRIVAL  PRICE  SEATS   CODE
# 0                AIR INDIA  08:00:00  10H 05M  18:00:00  27346     76  SK93V
# 1          BRITISH AIRWAYS  03:45:00  09H 30M  13:15:00  32342     52  PC7OC
# 2          BRITISH AIRWAYS  00:30:00  09H 25M  10:55:00  33564     98  OF94C
# 3                 EMIRATES  18:15:00  15H 15M  09:00:00  38354     69  4E23N
# 4  VIRGIN ATLANTIC AIRWAYS  14:50:00  09H 20M  00:10:00  38525     72  PG24X
# 5  VIRGIN ATLANTIC AIRWAYS  11:15:00  09H 20M  20:35:00  38576     98  NV03N
# 6                AIR INDIA  18:04:00  14H 06M  06:30:00  39277     67  TB92G

# %%
j=book()
df_new=pd.DataFrame()
if j in df_air.values:
    df_new=df_air[df_air["CODE"]==j]
    flag=1
else:
    print("Code you entered doesnot exist !!!!!")
    flag=0
    while(flag!=1):
        j=book()
        if j in df_air.values:
            flag=1
            df_new=df_air[df_air["CODE"]==j]
        else:
            print("Code you entered doesnot exist !!!!!")
            print("Try again!!!!!!!")
df_new
# Out:
# Please choose the serial number of airline you want:abcd
# Code you entered doesnot exist !!!!!
# Please choose the serial number of airline you want:PC7OC
#           AIRLINES DEPARTURE DURATION   ARRIVAL  PRICE  SEATS   CODE
# 1  BRITISH AIRWAYS  03:45:00  09H 30M  13:15:00  32342     52  PC7OC

# %%
information={}
ticket=int(input("Enter the number of tickets you want to book:"))
if(ticket>0 and ticket<=20):
    print("Please insert correct passenger details(as per ID)")
    number=int(input("Enter your phone number:"))
    for i in range(1,ticket+1):
        listinfo=[]
        Fname=str(input("Please enter your First name: "))
        Lname=str(input("Please enter your Last name: "))
        age=int(input("Please enter your age: "))
        country=str(input("Please enter your country of residence: "))
        print()
        print()
        listinfo.append(Fname)
        listinfo.append(Lname)
        listinfo.append(age)
        listinfo.append(country)
        
        information[i]=listinfo
elif(ticket>20):
    print("*******************Maximum 20 tickets can be booked at once !!!!!*************************************")
else:
    print("**********************Invalid***************************")
# Out:
# Enter the number of tickets you want to book:2
# Please insert correct passenger details(as per ID)
# Enter your phone number:9871236454
# Please enter your First name: AMAN
# Please enter your Last name: SHARMA
# Please enter your age: 20
# Please enter your country of residence: INDIA
#
#
# Please enter your First name: ANANT
# Please enter your Last name: GULIA
# Please enter your age: 23
# Please enter your country of residence: INDIA

# %%
print(information)
df_new
# Out:
# {1: ['AMAN', 'SHARMA', 20, 'INDIA'], 2: ['ANANT', 'GULIA', 23, 'INDIA']}
#           AIRLINES DEPARTURE DURATION   ARRIVAL  PRICE  SEATS   CODE
# 1  BRITISH AIRWAYS  03:45:00  09H 30M  13:15:00  32342     52  PC7OC

# %%
def TICKET(fname,lname,age,number,arrival,departure,seats,carrier,code,f,destination):

    print('------------------------BOARDING PASS------------------------')
    print('')
    print('Name: {} {}        Age:{}        Phone No.:{}'.format(fname,lname,age,number))
    print('')
    print('From:{}        Carrier:{}'.format(f, carrier))
    print('')
    print('To:{}        Departure:{}       Arrival:{}'.format(destination,departure,arrival))
    print('')
    print('Flight:{}         Seat No.:{}'.format(code,seats))
    print('')
    print('-------------------------------------------------------------')

# %%
import numpy as np
for i in information:
    m=information[i]
    fname=str(m[0])
    lname=str(m[1])
    age=m[2]
    add=str(m[3])
    m=df_new.values[0]
    arrival=m[1]
    departure=m[3]
    carrier=m[0]
    code=m[6]
    seat= np.random.randint(low=12, high=149, size=(1,))
    seats=seat[0]
    TICKET(fname.upper(),lname.upper(),age,number,arrival,departure,seats,carrier,code,f,d)
    print()
    print()
    print()
# Out:
# ------------------------BOARDING PASS------------------------
#
# Name: AMAN SHARMA        Age:20        Phone No.:9871236454
#
# From:DELHI        Carrier:BRITISH AIRWAYS
#
# To:LONDON        Departure:13:15:00       Arrival:03:45:00
#
# Flight:PC7OC         Seat No.:48
#
# -------------------------------------------------------------
#
#
#
# ------------------------BOARDING PASS------------------------
#
# Name: ANANT GULIA        Age:23        Phone No.:9871236454
#
# From:DELHI        Carrier:BRITISH AIRWAYS
#
# To:LONDON        Departure:13:15:00       Arrival:03:45:00
#
# Flight:PC7OC         Seat No.:43
#
# -------------------------------------------------------------

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# # EXIT
